# %% [markdown]
# # Symptoms over time

# %%
import pandas as pd
import numpy as np

# %%
tested_complete = pd.read_csv('base_MOH_data/corona_tested_individuals_ver_00158.csv')
# Out:
# D:\bin\anaconda3\envs\jupyter_environment\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (7,8) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
tested_complete.head(5)
# Out:
#     test_date  cough  fever  sore_throat  shortness_of_breath  head_ache  \
# 0  2021-07-04      0      1            0                    0          1
# 1  2021-07-04      0      0            0                    0          0
# 2  2021-07-04      0      0            0                    0          0
# 3  2021-07-04      0      0            0                    0          0
# 4  2021-07-04      0      0            0                    0          0
#
#   corona_result age_60_and_above gender         test_indication
# 0         חיובי              NaN   נקבה  Contact with confirmed
# 1         שלילי              NaN   נקבה                   Other
# 2         שלילי              NaN    זכר                   Other
# 3           אחר              NaN   נקבה                   Other
# 4           אחר              NaN    NaN                   Other

# %%
coughers = tested_complete[tested_complete.cough == 1 ]
sobers = tested_complete[tested_complete.shortness_of_breath == 1 ]
sobers[sobers.corona_result == "חיובי"]
# Out:
#           test_date  cough  fever  sore_throat  shortness_of_breath  \
# 265      2021-07-04      1      1            0                    1
# 273      2021-07-04      0      0            0                    1
# 323      2021-07-04      0      0            0                    1
# 12481    2021-07-03      1      0            0                    1
# 12568    2021-07-03      1      1            0                    1
# ...             ...    ...    ...          ...                  ...
# 6003265  2020-03-12      0      1            1                    1
# 6003275  2020-03-12      0      0            0                    1
# 6003302  2020-03-12      0      1            0                    1
# 6003316  2020-03-12      1      0            0                    1
# 6003324  2020-03-12      1      0            0                    1
#
#          head_ache corona_result age_60_and_above gender  \
# 265              1         חיובי              NaN   נקבה
# ...

# %% [markdown]
# ## So shortness of breath can be the only presenting symptom in some cases, but we see in many cases people have multiple symptoms.
# We might want to look at single symptom presenters over time, and see how they envolve. First let's look at all our positives

# %%
positive_tested = tested_complete[tested_complete.corona_result == 'חיובי']
#positive_tested['cough_to_fever_ratio'] = positive_tested.cough/positive_tested.fever

# %%
grouped_pos = positive_tested.groupby('test_date').sum()
grouped_pos.to_csv('grouped_pos_plus.csv')

# %%
grouped_pos
# Out:
#             cough  fever  sore_throat  shortness_of_breath  head_ache
# test_date
# 2020-03-11     12     14           13                    0          6
# 2020-03-12     15     12            6                    7          3
# 2020-03-13     15     11            5                    3          4
# 2020-03-14     21     16            6                    4          8
# 2020-03-15     31     22           13                   10          9
# ...           ...    ...          ...                  ...        ...
# 2021-06-30     19     17            5                    1         15
# 2021-07-01      9      6            7                    0          4
# 2021-07-02     12     12            3                    0         15
# 2021-07-03     11     10            0                    3          3
# 2021-07-04     25     30           15                    3         33
#
# [478 rows x 5 columns]
